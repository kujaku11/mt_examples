# %% [markdown]
# # Make MTH5 from IRIS Data Managment Center v0.2.0
#
# **Note:** this example assumes that data availability (Network, Station, Channel, Start, End) are all previously known.  If you do not know the data that you want to download use [IRIS tools](https://ds.iris.edu/ds/nodes/dmc/tools/##) to get data availability.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
from mth5.mth5 import MTH5
from mth5.clients.make_mth5 import FDSN

from matplotlib import pyplot as plt
#%matplotlib widget

# %% [markdown]
# ## Set the path to save files to as the current working directory

# %%
default_path = Path().cwd()
print(default_path)
# Out:
# C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mt_examples\notebooks\mth5

# %% [markdown]
# ## Initialize a MakeMTH5 object
#
# Here, we are setting the MTH5 file version to 0.2.0 so that we can have multiple surveys in a single file.  Also, setting the client to "IRIS".  Here, we are using `obspy.clients` tools for the request.  Here are the available [FDSN clients](https://docs.obspy.org/packages/obspy.clients.fdsn.html).
#
# **Note:** Only the "IRIS" client has been tested.

# %%
fdsn_object = FDSN(mth5_version='0.2.0')
fdsn_object.client = "IRIS"

# %% [markdown]
# ## Make the data inquiry as a DataFrame
#
# There are a few ways to make the inquiry to request data.
#
# 1. Make a DataFrame by hand.  Here we will make a list of entries and then create a DataFrame with the proper column names
# 2. You can create a CSV file with a row for each entry. There are some formatting that you need to be aware of.  That is the column names and making sure that date-times are YYYY-MM-DDThh:mm:ss
#
#
# | Column Name         |   Description                                                                                                 |
# | ------------------- | --------------------------------------------------------------------------------------------------------------|
# | **network**         | [FDSN Network code (2 letters)](http://www.fdsn.org/networks/)                                                |
# | **station**         | [FDSN Station code (usually 5 characters)](https://ds.iris.edu/ds/nodes/dmc/data/formats/seed-channel-naming/)|
# | **location**        | [FDSN Location code (typically not used for MT)](http://docs.fdsn.org/projects/source-identifiers/en/v1.0/location-codes.html) |
# | **channel**         | [FDSN Channel code (3 characters)](http://docs.fdsn.org/projects/source-identifiers/en/v1.0/channel-codes.html)|
# | **start**           | Start time (YYYY-MM-DDThh:mm:ss) UTC |
# | **end**             | End time (YYYY-MM-DDThh:mm:ss) UTC  |
#
# #### From IRIS Metadata
#
# Here are the station running during WYYS2, the original transfer function was processed with MTF20.
#
# | Station | Start | End |
# |---------|-------|-----|
# | MTF18 | 2009-07-11T00:07:55.0000 | 2009-08-28T21:31:41.0000 |
# | MTF19 | 2009-07-10T00:17:16.0000 | 2009-09-16T19:39:22.0000 |
# | MTF20 | 2009-07-03T22:38:13.0000 | 2009-08-13T17:15:39.0000 |
# | MTF21 | 2009-07-31T21:45:22.0000 | 2009-09-18T23:56:11.0000 |
# | WYI17 | 2009-07-13T22:17:15.0000 | 2009-08-04T19:41:33.0000 |
# | WYI21 | 2009-07-27T07:26:00.0000 | 2009-09-11T16:36:30.0000 |
# | WYJ18 | 2009-07-13T00:58:30.0000 | 2009-08-03T19:39:24.0000 |
# | WYJ21 | 2009-07-23T22:23:20.0000 | 2009-08-16T21:03:53.0000 |
# | WYK21 | 2009-07-22T22:01:44.0000 | 2009-08-06T12:11:52.0000 |
# | WYL21 | 2009-07-21T20:27:41.0000 | 2009-08-18T17:56:39.0000 |
# | WYYS1 | 2009-07-14T21:58:53.0000 | 2009-08-05T21:14:56.0000 |
# | WYYS2 | 2009-07-15T22:43:28.0000 | 2009-08-20T00:17:06.0000 |
#
# Here are the station running during WYYS3, the original transfer function was processed with MTC18
#
# | Station | Start | End |
# |---------|-------|-----|
# | MTC18 | 2009-08-21T21:52:53.0000 | 2009-09-13T00:02:18.0000 |
# | MTE18 | 2009-08-07T20:40:38.0000 | 2009-08-28T19:03:01.0000 |
# | MTE19 | 2009-08-12T22:45:47.0000 | 2009-09-02T17:10:53.0000 |
# | MTE20 | 2009-08-10T21:12:58.0000 | 2009-09-19T20:25:30.0000 |
# | MTE21 | 2009-08-09T02:45:02.0000 | 2009-08-30T21:43:43.0000 |
# | WYH21 | 2009-08-01T22:50:53.0000 | 2009-08-24T20:23:03.0000 |
# | WYG21 | 2009-08-03T02:56:34.0000 | 2009-08-18T19:56:53.0000 |
# | WYYS3 | 2009-08-20T01:55:41.0000 | 2009-09-17T20:04:21.0000 |
#
# In the examples below we will just download the original remote references, but as an excersize you could add in some other stations.

# %%
channels = ["LFE", "LFN", "LFZ", "LQE", "LQN"]
CAS04 = ["8P", "CAS04",  '2020-06-02T19:00:00', '2020-07-13T19:00:00'] 
NVR08 = ["8P", "NVR08", '2020-06-02T19:00:00', '2020-07-13T19:00:00']

request_list = []
for entry in [CAS04, NVR08]:
    for channel in channels:
        request_list.append(
            [entry[0], entry[1], "", channel, entry[2], entry[3]]
        )

# Turn list into dataframe
request_df =  pd.DataFrame(request_list, columns=fdsn_object.request_columns) 
request_df
# Out:
#   network station location channel                start                  end
# 0      8P   CAS04              LFE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 1      8P   CAS04              LFN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 2      8P   CAS04              LFZ  2020-06-02T19:00:00  2020-07-13T19:00:00
# 3      8P   CAS04              LQE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 4      8P   CAS04              LQN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 5      8P   NVR08              LFE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 6      8P   NVR08              LFN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 7      8P   NVR08              LFZ  2020-06-02T19:00:00  2020-07-13T19:00:00
# 8      8P   NVR08              LQE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 9      8P   NVR08              LQN  2020-06-02T19:00:00  2020-07-13T19:00:00

# %% [markdown]
# ## Save the request as a CSV
#
# Its helpful to be able to save the request as a CSV and modify it and use it later.  A CSV can be input as a request to `MakeMTH5`

# %%
request_df.to_csv(default_path.joinpath("fdsn_request.csv"))

# %% [markdown]
# ## Get only the metadata from IRIS
#
# It can be helpful to make sure that your request is what you would expect.  For that you can request only the metadata from IRIS.  The request is quick and light so shouldn't need to worry about the speed.  This returns a StationXML file and is loaded into an `obspy.Inventory` object.

# %%
inventory, data = fdsn_object.get_inventory_from_df(request_df, data=False)

# %% [markdown]
# Have a look at the Inventory to make sure it contains what is requested.

# %%
inventory
# Out:
# Inventory created at 2024-02-16T17:27:49.399052Z
# 	Created by: ObsPy 1.4.0
# 		    https://www.obspy.org
# 	Sending institution: MTH5
# 	Contains:
# 		Networks (1):
# 			8P
# 		Stations (2):
# 			8P.CAS04 (Corral Hollow, CA, USA)
# 			8P.NVR08 (Rhodes Salt Marsh, NV, USA)
# 		Channels (13):
# 			8P.CAS04..LFZ, 8P.CAS04..LFN, 8P.CAS04..LFE, 8P.CAS04..LQN (2x),
# 			8P.CAS04..LQE (3x), 8P.NVR08..LFZ, 8P.NVR08..LFN, 8P.NVR08..LFE,
# 			8P.NVR08..LQN, 8P.NVR08..LQE

# %% [markdown]
# ## Make an MTH5 from a request
#
# Now that we've created a request, and made sure that its what we expect, we can make an MTH5 file.  The input can be either the DataFrame or the CSV file.
#
# We are going to time it just to get an indication how long it might take.  Should take about 4 minutes.
#
# **Note:** we are setting `interact=False`.  If you want to just to keep the file open to interogat it set `interact=True`.

# %%
# %%time

mth5_object = fdsn_object.make_mth5_from_fdsn_client(request_df, interact=False)

print(f"Created {mth5_object}")
# Out:
# 2024-02-16T09:28:07.730978-0800 | WARNING | mth5.mth5 | open_mth5 | 8P_CAS04_NVR08.h5 will be overwritten in 'w' mode
# 2024-02-16T09:28:08.224093-0800 | INFO | mth5.mth5 | _initialize_file | Initialized MTH5 0.2.0 file C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mt_examples\notebooks\mth5\8P_CAS04_NVR08.h5 in mode w
# 2024-02-16T09:30:08.684160-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:08.699813-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_92.000 to a CoefficientFilter.
# 2024-02-16T09:30:08.792751-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:08.793325-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_92.000 to a CoefficientFilter.
# 2024-02-16T09:30:08.875955-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:08.884960-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_92.000 to a CoefficientFilter.
# 2024-02-16T09:30:08.981161-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:08.997145-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_92.000 to a CoefficientFilter.
# 2024-02-16T09:30:09.085097-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:09.113307-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_92.000 to a CoefficientFilter.
# 2024-02-16T09:30:09.372250-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:09.393175-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_94.000 to a CoefficientFilter.
# 2024-02-16T09:30:09.475843-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_si_units to a CoefficientFilter.
# 2024-02-16T09:30:09.484848-0800 | INFO | mt_metadata.timeseries.filters.obspy_stages | create_filter_from_stage | Converting PoleZerosResponseStage electric_dipole_94.000 to a CoefficientFilter.
# 2024-02-16T09:30:12.281241-0800 | INFO | mth5.groups.base | _add_group | RunGroup a already exists, returning existing group.
# 2024-02-16T09:30:12.546137-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | start time of dataset 2020-06-02T19:00:00+00:00 does not match metadata start 2020-06-02T18:41:43+00:00 updating metatdata value to 2020-06-02T19:00:00+00:00
# 2024-02-16T09:30:12.824020-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:13.324753-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:13.647372-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:13.945446-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:14.268898-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:14.381114-0800 | INFO | mth5.groups.base | _add_group | RunGroup b already exists, returning existing group.
# 2024-02-16T09:30:15.459622-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:15.793920-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:16.132138-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:16.460818-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:16.829996-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:16.945961-0800 | INFO | mth5.groups.base | _add_group | RunGroup c already exists, returning existing group.
# 2024-02-16T09:30:18.616880-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:18.963634-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:19.291874-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:19.646231-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:19.993899-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:20.132074-0800 | INFO | mth5.groups.base | _add_group | RunGroup d already exists, returning existing group.
# 2024-02-16T09:30:21.077479-0800 | WARNING | mth5.timeseries.run_ts | validate_metadata | end time of dataset 2020-07-13T19:00:00+00:00 does not match metadata end 2020-07-13T21:46:12+00:00 updating metatdata value to 2020-07-13T19:00:00+00:00
# 2024-02-16T09:30:21.402296-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id d. Setting to ch.run_metadata.id to d
# 2024-02-16T09:30:21.731137-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id d. Setting to ch.run_metadata.id to d
# 2024-02-16T09:30:22.114034-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id d. Setting to ch.run_metadata.id to d
# 2024-02-16T09:30:22.463469-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id d. Setting to ch.run_metadata.id to d
# 2024-02-16T09:30:22.833130-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id d. Setting to ch.run_metadata.id to d
# 2024-02-16T09:30:22.995819-0800 | INFO | mth5.groups.base | _add_group | RunGroup a already exists, returning existing group.
# 2024-02-16T09:30:23.461288-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:23.832049-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:24.170147-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:24.498301-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:24.817662-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id a. Setting to ch.run_metadata.id to a
# 2024-02-16T09:30:24.937250-0800 | INFO | mth5.groups.base | _add_group | RunGroup b already exists, returning existing group.
# 2024-02-16T09:30:26.461193-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:27.205719-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:27.710444-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:28.141697-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:28.574409-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id b. Setting to ch.run_metadata.id to b
# 2024-02-16T09:30:28.712104-0800 | INFO | mth5.groups.base | _add_group | RunGroup c already exists, returning existing group.
# 2024-02-16T09:30:29.912509-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:30.247836-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:30.670187-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:31.035159-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:31.415368-0800 | WARNING | mth5.groups.run | from_runts | Channel run.id sr1_001 !=  group run.id c. Setting to ch.run_metadata.id to c
# 2024-02-16T09:30:31.637516-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mt_examples\notebooks\mth5\8P_CAS04_NVR08.h5
# 2024-02-16T09:30:31.653083-0800 | WARNING | mth5.mth5 | filename | MTH5 file is not open or has not been created yet. Returning default name
# Created C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mt_examples\notebooks\mth5\8P_CAS04_NVR08.h5
# CPU times: total: 24.7 s
# Wall time: 2min 23s

# %%
# open file already created
mth5_object = MTH5()
mth5_object.open_mth5("8P_CAS04_NVR08.h5")
# Out:
# /:
# ====================
#     |- Group: Experiment
#     --------------------
#         |- Group: Reports
#         -----------------
#         |- Group: Standards
#         -------------------
#             --> Dataset: summary
#             ......................
#         |- Group: Surveys
#         -----------------
#             |- Group: CONUS_South
#             ---------------------
#                 |- Group: Filters
#                 -----------------
#                     |- Group: coefficient
#                     ---------------------
#                         |- Group: electric_analog_to_digital
#                         ------------------------------------
#                         |- Group: electric_dipole_92.000
#                         --------------------------------
#                         |- Group: electric_dipole_94.000
#                         --------------------------------
#                         |- Group: electric_si_units
#                         ---------------------------
#                         |- Group: magnetic_analog_to_digital
#                         ------------------------------------
#                     |- Group: fap
#                     -------------
#                     |- Group: fir
#                     -------------
#                     |- Group: time_delay
#                     --------------------
#                         |- Group: electric_time_offset
#                         ------------------------------
#                         |- Group: hx_time_offset
#                         ------------------------
#                         |- Group: hy_time_offset
#                         ------------------------
#                         |- Group: hz_time_offset
#                         ------------------------
#                     |- Group: zpk
#                     -------------
#                         |- Group: electric_butterworth_high_pass
#                         ----------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                         |- Group: electric_butterworth_low_pass
#                         ---------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                         |- Group: magnetic_butterworth_low_pass
#                         ---------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                 |- Group: Reports
#                 -----------------
#                 |- Group: Standards
#                 -------------------
#                     --> Dataset: summary
#                     ......................
#                 |- Group: Stations
#                 ------------------
#                     |- Group: CAS04
#                     ---------------
#                         |- Group: Fourier_Coefficients
#                         ------------------------------
#                         |- Group: Transfer_Functions
#                         ----------------------------
#                         |- Group: a
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: b
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: c
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: d
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                     |- Group: NVR08
#                     ---------------
#                         |- Group: Fourier_Coefficients
#                         ------------------------------
#                         |- Group: Transfer_Functions
#                         ----------------------------
#                         |- Group: a
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: b
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: c
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#         --> Dataset: channel_summary
#         ..............................
#         --> Dataset: tf_summary
#         .........................

# %% [markdown]
# ### Add transfer function

# %%
from mt_metadata.transfer_functions.core import TF

# %%
cas04_tf = TF()
cas04_tf.read(r"USMTArray.CAS04.2020.edi")

# %%
cas04_tf.survey = "CONUS_South"

# %%
mth5_object.add_transfer_function(cas04_tf)
# Out:
# /Experiment/Surveys/CONUS_South/Stations/CAS04/Transfer_Functions/CAS04:
# ====================
#     --> Dataset: period
#     .....................
#     --> Dataset: transfer_function
#     ................................
#     --> Dataset: transfer_function_error
#     ......................................

# %% [markdown]
# ## Have a look at the contents of the created file

# %%
mth5_object
# Out:
# /:
# ====================
#     |- Group: Experiment
#     --------------------
#         |- Group: Reports
#         -----------------
#         |- Group: Standards
#         -------------------
#             --> Dataset: summary
#             ......................
#         |- Group: Surveys
#         -----------------
#             |- Group: CONUS_South
#             ---------------------
#                 |- Group: Filters
#                 -----------------
#                     |- Group: coefficient
#                     ---------------------
#                         |- Group: electric_analog_to_digital
#                         ------------------------------------
#                         |- Group: electric_dipole_92.000
#                         --------------------------------
#                         |- Group: electric_dipole_94.000
#                         --------------------------------
#                         |- Group: electric_si_units
#                         ---------------------------
#                         |- Group: magnetic_analog_to_digital
#                         ------------------------------------
#                     |- Group: fap
#                     -------------
#                     |- Group: fir
#                     -------------
#                     |- Group: time_delay
#                     --------------------
#                         |- Group: electric_time_offset
#                         ------------------------------
#                         |- Group: hx_time_offset
#                         ------------------------
#                         |- Group: hy_time_offset
#                         ------------------------
#                         |- Group: hz_time_offset
#                         ------------------------
#                     |- Group: zpk
#                     -------------
#                         |- Group: electric_butterworth_high_pass
#                         ----------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                         |- Group: electric_butterworth_low_pass
#                         ---------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                         |- Group: magnetic_butterworth_low_pass
#                         ---------------------------------------
#                             --> Dataset: poles
#                             ....................
#                             --> Dataset: zeros
#                             ....................
#                 |- Group: Reports
#                 -----------------
#                 |- Group: Standards
#                 -------------------
#                     --> Dataset: summary
#                     ......................
#                 |- Group: Stations
#                 ------------------
#                     |- Group: CAS04
#                     ---------------
#                         |- Group: Fourier_Coefficients
#                         ------------------------------
#                         |- Group: Transfer_Functions
#                         ----------------------------
#                         |- Group: a
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: b
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: c
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: d
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                     |- Group: NVR08
#                     ---------------
#                         |- Group: Fourier_Coefficients
#                         ------------------------------
#                         |- Group: Transfer_Functions
#                         ----------------------------
#                         |- Group: a
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: b
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#                         |- Group: c
#                         -----------
#                             --> Dataset: ex
#                             .................
#                             --> Dataset: ey
#                             .................
#                             --> Dataset: hx
#                             .................
#                             --> Dataset: hy
#                             .................
#                             --> Dataset: hz
#                             .................
#         --> Dataset: channel_summary
#         ..............................
#         --> Dataset: tf_summary
#         .........................

# %% [markdown]
# ## Channel Summary
#
# A convenience table is supplied with an MTH5 file.  This table provides some information about each channel that is present in the file.  It also provides columns `hdf5_reference`, `run_hdf5_reference`, and `station_hdf5_reference`, these are internal references within an HDF5 file and can be used to directly access a group or dataset by using `mth5_object.from_reference` method.
#
# **Note:** When a MTH5 file is close the table is resummarized so when you open the file next the `channel_summary` will be up to date. Same with the `tf_summary`.

# %%
mth5_object.channel_summary.clear_table()
mth5_object.channel_summary.summarize()

ch_df = mth5_object.channel_summary.to_dataframe()
ch_df
# Out:
#          survey station run   latitude   longitude  elevation component  \
# 0   CONUS South   CAS04   a  37.633351 -121.468382   329.3875        ex
# 1   CONUS South   CAS04   a  37.633351 -121.468382   329.3875        ey
# 2   CONUS South   CAS04   a  37.633351 -121.468382   329.3875        hx
# 3   CONUS South   CAS04   a  37.633351 -121.468382   329.3875        hy
# 4   CONUS South   CAS04   a  37.633351 -121.468382   329.3875        hz
# 5   CONUS South   CAS04   b  37.633351 -121.468382   329.3875        ex
# 6   CONUS South   CAS04   b  37.633351 -121.468382   329.3875        ey
# 7   CONUS South   CAS04   b  37.633351 -121.468382   329.3875        hx
# 8   CONUS South   CAS04   b  37.633351 -121.468382   329.3875        hy
# 9   CONUS South   CAS04   b  37.633351 -121.468382   329.3875        hz
# 10  CONUS South   CAS04   c  37.633351 -121.468382   329.3875        ex
# 11  CONUS South   CAS04   c  37.633351 -121.468382   329.3875        ey
# 12  CONUS South   CAS04   c  37.633351 -121.468382   329.3875        hx
# 13  CONUS South   CAS04   c  37.633351 -121.468382   329.3875        hy
# 14  CONUS South   CAS04   c  37.633351 -121.468382   329.3875        hz
# 15  CONUS South   CAS04   d  37.633351 -121.468382   329.3875        ex
# 16  CONUS South   CAS04   d  37.633351 -121.468382   329.3875        ey
# 17  CONUS South   CAS04   d  37.633351 -121.468382   329.3875        hx
# 18  CONUS South   CAS04   d  37.633351 -121.468382   329.3875        hy
# 19  CONUS South   CAS04   d  37.633351 -121.468382   329.3875        hz
# 20  CONUS South   NVR08   a  38.326630 -118.082382  1375.4250        ex
# 21  CONUS South   NVR08   a  38.326630 -118.082382  1375.4250        ey
# 22  CONUS South   NVR08   a  38.326630 -118.082382  1375.4250        hx
# 23  CONUS South   NVR08   a  38.326630 -118.082382  1375.4250        hy
# 24  CONUS South   NVR08   a  38.326630 -118.082382  1375.4250        hz
# 25  CONUS South   NVR08   b  38.326630 -118.082382  1375.4250        ex
# 26  CONUS South   NVR08   b  38.326630 -118.082382  1375.4250        ey
# 27  CONUS South   NVR08   b  38.326630 -118.082382  1375.4250        hx
# 28  CONUS South   NVR08   b  38.326630 -118.082382  1375.4250        hy
# 29  CONUS South   NVR08   b  38.326630 -118.082382  1375.4250        hz
# 30  CONUS South   NVR08   c  38.326630 -118.082382  1375.4250        ex
# 31  CONUS South   NVR08   c  38.326630 -118.082382  1375.4250        ey
# 32  CONUS South   NVR08   c  38.326630 -118.082382  1375.4250        hx
# 33  CONUS South   NVR08   c  38.326630 -118.082382  1375.4250        hy
# 34  CONUS South   NVR08   c  38.326630 -118.082382  1375.4250        hz
#
#                        start                       end  n_samples  \
# 0  2020-06-02 19:00:00+00:00 2020-06-02 22:07:46+00:00      11267
# 1  2020-06-02 19:00:00+00:00 2020-06-02 22:07:46+00:00      11267
# 2  2020-06-02 19:00:00+00:00 2020-06-02 22:07:46+00:00      11267
# 3  2020-06-02 19:00:00+00:00 2020-06-02 22:07:46+00:00      11267
# 4  2020-06-02 19:00:00+00:00 2020-06-02 22:07:46+00:00      11267
# 5  2020-06-02 22:24:55+00:00 2020-06-12 17:52:23+00:00     847649
# 6  2020-06-02 22:24:55+00:00 2020-06-12 17:52:23+00:00     847649
# 7  2020-06-02 22:24:55+00:00 2020-06-12 17:52:23+00:00     847649
# 8  2020-06-02 22:24:55+00:00 2020-06-12 17:52:23+00:00     847649
# 9  2020-06-02 22:24:55+00:00 2020-06-12 17:52:23+00:00     847649
# 10 2020-06-12 18:32:17+00:00 2020-07-01 17:32:59+00:00    1638043
# 11 2020-06-12 18:32:17+00:00 2020-07-01 17:32:59+00:00    1638043
# 12 2020-06-12 18:32:17+00:00 2020-07-01 17:32:59+00:00    1638043
# 13 2020-06-12 18:32:17+00:00 2020-07-01 17:32:59+00:00    1638043
# 14 2020-06-12 18:32:17+00:00 2020-07-01 17:32:59+00:00    1638043
# 15 2020-07-01 19:36:55+00:00 2020-07-13 19:00:00+00:00    1034586
# 16 2020-07-01 19:36:55+00:00 2020-07-13 19:00:00+00:00    1034586
# 17 2020-07-01 19:36:55+00:00 2020-07-13 19:00:00+00:00    1034586
# 18 2020-07-01 19:36:55+00:00 2020-07-13 19:00:00+00:00    1034586
# 19 2020-07-01 19:36:55+00:00 2020-07-13 19:00:00+00:00    1034586
# 20 2020-06-03 19:10:11+00:00 2020-06-03 19:57:51+00:00       2861
# 21 2020-06-03 19:10:11+00:00 2020-06-03 19:57:51+00:00       2861
# 22 2020-06-03 19:10:11+00:00 2020-06-03 19:57:51+00:00       2861
# 23 2020-06-03 19:10:11+00:00 2020-06-03 19:57:51+00:00       2861
# 24 2020-06-03 19:10:11+00:00 2020-06-03 19:57:51+00:00       2861
# 25 2020-06-03 20:14:13+00:00 2020-06-14 16:56:02+00:00     938510
# 26 2020-06-03 20:14:13+00:00 2020-06-14 16:56:02+00:00     938510
# 27 2020-06-03 20:14:13+00:00 2020-06-14 16:56:02+00:00     938510
# 28 2020-06-03 20:14:13+00:00 2020-06-14 16:56:02+00:00     938510
# 29 2020-06-03 20:14:13+00:00 2020-06-14 16:56:02+00:00     938510
# 30 2020-06-14 18:00:44+00:00 2020-06-24 15:55:46+00:00     856503
# 31 2020-06-14 18:00:44+00:00 2020-06-24 15:55:46+00:00     856503
# 32 2020-06-14 18:00:44+00:00 2020-06-24 15:55:46+00:00     856503
# 33 2020-06-14 18:00:44+00:00 2020-06-24 15:55:46+00:00     856503
# 34 2020-06-14 18:00:44+00:00 2020-06-24 15:55:46+00:00     856503
#
#     sample_rate measurement_type  azimuth  tilt           units  \
# 0           1.0         electric     13.2   0.0  digital counts
# 1           1.0         electric    103.2   0.0  digital counts
# 2           1.0         magnetic     13.2   0.0  digital counts
# 3           1.0         magnetic    103.2   0.0  digital counts
# 4           1.0         magnetic      0.0  90.0  digital counts
# 5           1.0         electric     13.2   0.0  digital counts
# 6           1.0         electric    103.2   0.0  digital counts
# 7           1.0         magnetic     13.2   0.0  digital counts
# 8           1.0         magnetic    103.2   0.0  digital counts
# 9           1.0         magnetic      0.0  90.0  digital counts
# 10          1.0         electric     13.2   0.0  digital counts
# 11          1.0         electric    103.2   0.0  digital counts
# 12          1.0         magnetic     13.2   0.0  digital counts
# 13          1.0         magnetic    103.2   0.0  digital counts
# 14          1.0         magnetic      0.0  90.0  digital counts
# 15          1.0         electric     13.2   0.0  digital counts
# 16          1.0         electric    103.2   0.0  digital counts
# 17          1.0         magnetic     13.2   0.0  digital counts
# 18          1.0         magnetic    103.2   0.0  digital counts
# 19          1.0         magnetic      0.0  90.0  digital counts
# 20          1.0         electric     12.6   0.0  digital counts
# 21          1.0         electric    102.6   0.0  digital counts
# 22          1.0         magnetic     12.6   0.0  digital counts
# 23          1.0         magnetic    102.6   0.0  digital counts
# 24          1.0         magnetic      0.0  90.0  digital counts
# 25          1.0         electric     12.6   0.0  digital counts
# 26          1.0         electric    102.6   0.0  digital counts
# 27          1.0         magnetic     12.6   0.0  digital counts
# 28          1.0         magnetic    102.6   0.0  digital counts
# 29          1.0         magnetic      0.0  90.0  digital counts
# 30          1.0         electric     12.6   0.0  digital counts
# 31          1.0         electric    102.6   0.0  digital counts
# 32          1.0         magnetic     12.6   0.0  digital counts
# 33          1.0         magnetic    102.6   0.0  digital counts
# 34          1.0         magnetic      0.0  90.0  digital counts
#
#              hdf5_reference       run_hdf5_reference   station_hdf5_reference
# 0   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 1   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 2   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 3   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 4   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 5   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 6   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 7   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 8   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 9   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 10  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 11  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 12  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 13  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 14  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 15  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 16  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 17  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 18  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 19  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 20  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 21  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 22  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 23  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 24  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 25  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 26  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 27  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 28  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 29  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 30  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 31  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 32  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 33  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 34  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>

# %% [markdown]
# ## Have a look at a station
#
# Lets grab one station `CAS04` and have a look at its metadata and contents.
# Here we will grab it from the `mth5_object`.

# %%
cas04 = mth5_object.get_station("CAS04", survey="CONUS_South")
cas04.metadata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/envs/geophys/lib/python3.9/site-packages/mth5/mth5.py:1169, in MTH5.get_station(self, station_name, survey)
#    1168 try:
# -> 1169     return groups.StationGroup(self.__hdf5_obj[station_path])
#    1170 except KeyError:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/conda/envs/geophys/lib/python3.9/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:190, in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'
#
# During handling of the above exception, another exception occurred:
#
# MTH5Error                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 wyys2 = mth5_object.get_station("WYYS2", survey="Kansas_2017_Long_Period")
#       2 wyys2.metadata
#
# File /opt/conda/envs/geophys/lib/python3.9/site-packages/mth5/mth5.py:1171, in MTH5.get_station(self, station_name, survey)
#    1169     return groups.StationGroup(self.__hdf5_obj[station_path])
#    1170 except KeyError:
# -> 1171     raise MTH5Error(f"Could not find station {station_name}")
#
# MTH5Error: Could not find station WYYS2

# %% [markdown]
# ### Changing Metadata
# If you want to change the metadata of any group, be sure to use the `write_metadata` method.  Here's an example:

# %%
cas04.metadata.location.declination.value = 12.2
cas04.write_metadata()
print(cas04.metadata.location.declination)

# %% [markdown]
# ## Have a look at a single channel
#
# Let's pick out a channel and interogate it. There are a couple ways
# 1. Get a channel the first will be from the `hdf5_reference` [*demonstrated here*]
# 2. Get a channel from `mth5_object`
# 3. Get a station first then get a channel

# %%
ex = mth5_object.from_reference(ch_df.iloc[-6].hdf5_reference).to_channel_ts()
print(ex)

# %%
ex.channel_metadata

# %% [markdown]
# ## Calibrate time series data
# Most data loggers output data in digital counts.  Then a series of filters that represent the various instrument responses are applied to get the data into physical units.  The data can then be analyzed and processed. Commonly this is done during the processing step, but it is important to be able to look at time series data in physical units.  Here we provide a `remove_instrument_response` method in the `ChananelTS` object.  Here's an example:

# %%
print(ex.channel_response_filter)
ex.channel_response_filter.plot_response(np.logspace(0, 4, 50))

# %%
ex.remove_instrument_response(plot=True)

# %% [markdown]
# ## Have a look at a run
#
# Let's pick out a run, take a slice of it, and interogate it. There are a couple ways
# 1. Get a run the first will be from the `run_hdf5_reference` [*demonstrated here*]
# 2. Get a run from `mth5_object`
# 3. Get a station first then get a run

# %%
run_from_reference = mth5_object.from_reference(ch_df.iloc[0].run_hdf5_reference).to_runts(start=ch_df.iloc[0].start.isoformat(), n_samples=360)
print(run_from_reference)

# %%
run_from_reference.plot()

# %% [markdown]
# ### Calibrate Run

# %%
calibrated_run = run_from_reference.calibrate()
calibrated_run.plot()

# %% [markdown]
# ### Have a look at the transfer function summary

# %%
mth5_object.tf_summary.summarize()
tf_df = mth5_object.tf_summary.to_dataframe()
tf_df

# %% [markdown]
# ## Close MTH5
#
# We have now loaded in all the data we need for long period data.  We can now process these data using **Aurora** and have a look at the transfer functions using **MTpy**.

# %%
mth5_object.close_mth5()
# Out:
# 2024-02-16T09:36:19.636939-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing 8P_CAS04_NVR08.h5
