# %% [markdown]
# # MTH5 Example 06
#
# ## Make an MTH5 from LEMI data
#
# LEMI instruments are the long period instruments provided by IRIS.  These instruments sample at 1 second and output the data as text files that are a maximum of 1 day in length.  The text files contain information about each channel recorded in a single line.  A typical line looks like
#
# ```
# 2020 09 30 20 21 00 23813.621   729.816 41802.042  39.76  40.48   131.013  -111.026   164.166     9.715 13.01 2204.5 3404.83911 N 10712.84475 W 12 2 0
# ```
#
# where each column is
#
# ```
# year month day hour minute second bx by bz temperature_e temperature_h e1 e2 e3 e4 battery elevation latitude latitude_hemisphere longitude longitude_hemisphere n_satellites gps_fix time_difference
# ```
#
# A reader is provided with the mth5 module to parse these text files into `RunTS` objects.  The files contain little metadata so the user needs to input some important information.
#
# Note that the output LEMI424 files are calibrated to physical units, therefore no calibration is needed.
#
# This notebook provides an example of how to read in LEMI (.TXT) files into an MTH5.

# %%
from pathlib import Path
from mth5.mth5 import MTH5
from mth5.io.lemi import LEMICollection
from mth5 import read_file
# %matplotlib widget
# Out:
# 2022-12-13 19:38:42,509 [line 135] mth5.setup_logger - INFO: Logging file can be found C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mth5\logs\mth5_debug.log

# %% [markdown]
# ## LEMI Collection
#
# We will use the `LEMICollection` to assemble the *.txt* files into a logical order by schedule action or run. The output LEMI files include all data for each channel.
#
# **IMPORTANT:** `LEMICollection` assumes the given file path is for a single station.
#
# **Metadata:** we need to input the `station_id` and the `survey_id` to provide minimal metadata when making an MTH5 fild.
#
# The `LEMICollection.get_runs()` will return a two level ordered dictionary (`OrderedDict`).  The first level is keyed by station ID.  These objects are in turn ordered dictionaries by run ID.  Therefore you can loop over stations and runs.
#
# **Note**: `n_samples` is an estimate based on file size not the data.  To get an accurate number you should read in the full file.

# %% [markdown]
# ### Set the LEMI path to get the data.

# %%
lemi_path = Path().cwd().parent.parent.joinpath("data", "time_series", "lemi")

# %%
zc = LEMICollection(lemi_path)

# input some high level metadata
zc.station_id = "mt001"
zc.survey_id = "iris_test"

# %% [markdown]
# ### Get Run names
#
# Assign run names to the continuous blocks of data.  The runs will be assigned a number based on their start times with a name that looks like `sr{sample_rate}_{{run_number}:0{zeros}` --> `sr1_0001`. The returned value `runs` is an `OrderedDict` with keys as the run ID and values of a `pandas.DataFrame`, where each row provides information of each file read in.

# %%
runs = zc.get_runs(sample_rates=[1])
print(f"Found {len(runs)} station with {len(runs[list(runs.keys())[0]])} runs")
# Out:
# Found 1 station with 5 runs

# %% [markdown]
# Here we can see that there were a few short runs, likely tests to make sure everything was setup properly before the long run began.  Looks like the long run ran for about a week.  We can now use this information to read in the data into the proper run where the long run files will be combined into a single `RunTS` object.

# %%
for run_id, run_df in runs[zc.station_id].items():
    display(run_df)
# Out:
#       survey station       run                     start  \
# 0  iris_test   mt001  sr1_0001 2020-09-30 20:21:00+00:00
#
#                         end  channel_id  \
# 0 2020-09-30 20:28:15+00:00           1
#
#                                     component  \
# 0  temperature_e,temperature_h,e1,e2,bx,by,bz
#
#                                                   fn  sample_rate  file_size  \
# 0  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0      66272
#
#    n_samples  sequence_number instrument_id calibration_fn
# 0        436                0       LEMI424           None
#       survey station       run                     start  \
# 1  iris_test   mt001  sr1_0002 2020-09-30 20:29:00+00:00
#
#                         end  channel_id  \
# 1 2020-09-30 20:42:16+00:00           1
#
#                                     component  \
# 1  temperature_e,temperature_h,e1,e2,bx,by,bz
#
#                                                   fn  sample_rate  file_size  \
# 1  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0     121144
#
#    n_samples  sequence_number instrument_id calibration_fn
# 1        797                0       LEMI424           None
#       survey station       run                     start  \
# 2  iris_test   mt001  sr1_0003 2020-09-30 20:54:00+00:00
#
#                         end  channel_id  \
# 2 2020-09-30 21:11:01+00:00           1
#
#                                     component  \
# 2  temperature_e,temperature_h,e1,e2,bx,by,bz
#
#                                                   fn  sample_rate  file_size  \
# 2  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0     155344
#
#    n_samples  sequence_number instrument_id calibration_fn
# 2       1022                0       LEMI424           None
#       survey station       run                     start  \
# 3  iris_test   mt001  sr1_0004 2020-09-30 21:12:00+00:00
#
#                         end  channel_id  \
# 3 2020-09-30 21:13:45+00:00           1
#
#                                     component  \
# 3  temperature_e,temperature_h,e1,e2,bx,by,bz
#
#                                                   fn  sample_rate  file_size  \
# 3  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0      16112
#
#    n_samples  sequence_number instrument_id calibration_fn
# 3        106                0       LEMI424           None
#        survey station       run                     start  \
# 4   iris_test   mt001  sr1_0005 2020-09-30 21:14:00+00:00
# 5   iris_test   mt001  sr1_0005 2020-10-01 00:00:00+00:00
# 6   iris_test   mt001  sr1_0005 2020-10-02 00:00:00+00:00
# 7   iris_test   mt001  sr1_0005 2020-10-03 00:00:00+00:00
# 8   iris_test   mt001  sr1_0005 2020-10-04 00:00:00+00:00
# 9   iris_test   mt001  sr1_0005 2020-10-05 00:00:00+00:00
# 10  iris_test   mt001  sr1_0005 2020-10-06 00:00:00+00:00
# 11  iris_test   mt001  sr1_0005 2020-10-07 00:00:00+00:00
#
#                          end  channel_id  \
# 4  2020-09-30 23:59:59+00:00           1
# 5  2020-10-01 23:59:59+00:00           1
# 6  2020-10-02 23:59:59+00:00           1
# 7  2020-10-03 23:59:59+00:00           1
# 8  2020-10-04 23:59:59+00:00           1
# 9  2020-10-05 23:59:59+00:00           1
# 10 2020-10-06 23:59:59+00:00           1
# 11 2020-10-07 14:19:46+00:00           1
#
#                                      component  \
# 4   temperature_e,temperature_h,e1,e2,bx,by,bz
# 5   temperature_e,temperature_h,e1,e2,bx,by,bz
# 6   temperature_e,temperature_h,e1,e2,bx,by,bz
# 7   temperature_e,temperature_h,e1,e2,bx,by,bz
# 8   temperature_e,temperature_h,e1,e2,bx,by,bz
# 9   temperature_e,temperature_h,e1,e2,bx,by,bz
# 10  temperature_e,temperature_h,e1,e2,bx,by,bz
# 11  temperature_e,temperature_h,e1,e2,bx,by,bz
#
#                                                    fn  sample_rate  file_size  \
# 4   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0    1513920
# 5   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132800
# 6   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132800
# 7   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132800
# 8   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132800
# 9   C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132801
# 10  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0   13132800
# 11  C:\Users\jpeacock\OneDrive - DOI\Documents\Git...          1.0    7841224
#
#     n_samples  sequence_number instrument_id calibration_fn
# 4        9960                0       LEMI424           None
# 5       86400                0       LEMI424           None
# 6       86400                0       LEMI424           None
# 7       86400                0       LEMI424           None
# 8       86400                0       LEMI424           None
# 9       86400                0       LEMI424           None
# 10      86400                0       LEMI424           None
# 11      51587                0       LEMI424           None

# %% [markdown]
# ## Build MTH5
#
# Now that we have a logical collection of files, lets load them into an MTH5.  We will simply loop over the stations, runs, and channels in the ordered dictionary.
#
# There are a few things that to keep in mind:
#
# - The LEMI raw files come with very little metadata, so as a user you will have to manually input most of it.
# - The output files from a LEMI are already calibrated into units of nT and mV/km (I think), therefore there are no filters to apply to calibrate the data.

# %%
m = MTH5()
m.open_mth5(zc.file_path.joinpath("from_lemi.h5"))

# %%
survey_group = m.add_survey(zc.survey_id)
# Out:
# 2022-12-13 19:38:44,111 [line 286] mth5.groups.base.MasterSurvey.add_survey - INFO: survey iris_test already exists, returning existing group.

# %%
# %%time
for station_id in runs.keys():
    station_group = survey_group.stations_group.add_station(station_id)
    for run_id, run_df in runs[station_id].items():
        run_group = station_group.add_run(run_id)
        run_ts = read_file(run_df.fn.to_list())
        run_ts.run_metadata.id = run_id
        run_group.from_runts(run_ts)
    station_group.metadata.update(run_ts.station_metadata)
    station_group.write_metadata()
    station_group.update_station_metadata()

# update survey metadata from input station
survey_group.update_survey_metadata()
# Out:
# 2022-12-13 19:38:44,145 [line 311] mth5.groups.base.MasterStation.add_station - INFO: Station mt001 already exists, returning existing group.
# 2022-12-13 19:38:45,615 [line 759] mth5.groups.base.Station.add_run - INFO: run sr1_0001 already exists, returning existing group.
# 2022-12-13 19:39:10,702 [line 759] mth5.groups.base.Station.add_run - INFO: run sr1_0002 already exists, returning existing group.
# 2022-12-13 19:39:35,527 [line 759] mth5.groups.base.Station.add_run - INFO: run sr1_0003 already exists, returning existing group.
# 2022-12-13 19:40:05,330 [line 759] mth5.groups.base.Station.add_run - INFO: run sr1_0004 already exists, returning existing group.
# 2022-12-13 19:40:31,873 [line 759] mth5.groups.base.Station.add_run - INFO: run sr1_0005 already exists, returning existing group.
# 2022-12-13 19:40:42,170 [line 472] mth5.timeseries.run_ts.RunTS.validate_metadata - WARNING: end time of dataset 2020-10-07T17:05:46+00:00 does not match metadata end 2020-10-07T14:19:46+00:00 updating metatdata value to 2020-10-07T17:05:46+00:00
# Wall time: 2min 25s

# %% [markdown]
# #### MTH5 Structure
#
# Have a look at the MTH5 structure and make sure it looks correct.

# %%
m
# Out:
# /:
# ====================
#     |- Group: Experiment
#     --------------------
#         |- Group: Reports
#         -----------------
#         |- Group: Standards
#         -------------------
#             --> Dataset: summary
#             ......................
#         |- Group: Surveys
#         -----------------
#             |- Group: iris_test
#             -------------------
#                 |- Group: Filters
#                 -----------------
#                     |- Group: coefficient
#                     ---------------------
#                     |- Group: fap
#                     -------------
#                     |- Group: fir
#                     -------------
#                     |- Group: time_delay
#                     --------------------
#                     |- Group: zpk
#                     -------------
#                 |- Group: Reports
#                 -----------------
#                 |- Group: Standards
#                 -------------------
#                     --> Dataset: summary
#                     ......................
#                 |- Group: Stations
#                 ------------------
#                     |- Group: mt001
#                     ---------------
#                         |- Group: Transfer_Functions
#                         ----------------------------
#                         |- Group: sr1_0001
#                         ------------------
#                             --> Dataset: bx
#                             .................
#                             --> Dataset: by
#                             .................
#                             --> Dataset: bz
#                             .................
#                             --> Dataset: e1
#                             .................
#                             --> Dataset: e2
#                             .................
#                             --> Dataset: temperature_e
#                             ............................
#                             --> Dataset: temperature_h
#                             ............................
#                         |- Group: sr1_0002
#                         ------------------
#                             --> Dataset: bx
#                             .................
#                             --> Dataset: by
#                             .................
#                             --> Dataset: bz
#                             .................
#                             --> Dataset: e1
#                             .................
#                             --> Dataset: e2
#                             .................
#                             --> Dataset: temperature_e
#                             ............................
#                             --> Dataset: temperature_h
#                             ............................
#                         |- Group: sr1_0003
#                         ------------------
#                             --> Dataset: bx
#                             .................
#                             --> Dataset: by
#                             .................
#                             --> Dataset: bz
#                             .................
#                             --> Dataset: e1
#                             .................
#                             --> Dataset: e2
#                             .................
#                             --> Dataset: temperature_e
#                             ............................
#                             --> Dataset: temperature_h
#                             ............................
#                         |- Group: sr1_0004
#                         ------------------
#                             --> Dataset: bx
#                             .................
#                             --> Dataset: by
#                             .................
#                             --> Dataset: bz
#                             .................
#                             --> Dataset: e1
#                             .................
#                             --> Dataset: e2
#                             .................
#                             --> Dataset: temperature_e
#                             ............................
#                             --> Dataset: temperature_h
#                             ............................
#                         |- Group: sr1_0005
#                         ------------------
#                             --> Dataset: bx
#                             .................
#                             --> Dataset: by
#                             .................
#                             --> Dataset: bz
#                             .................
#                             --> Dataset: e1
#                             .................
#                             --> Dataset: e2
#                             .................
#                             --> Dataset: temperature_e
#                             ............................
#                             --> Dataset: temperature_h
#                             ............................
#         --> Dataset: channel_summary
#         ..............................
#         --> Dataset: tf_summary
#         .........................

# %% [markdown]
# ### Channel Summary
#
# Have a look at the channel summary and make sure everything looks good.

# %%
m.channel_summary.summarize()
m.channel_summary.to_dataframe()
# Out:
#        survey station       run   latitude   longitude  elevation  \
# 0   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 1   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 2   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 3   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 4   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 5   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 6   iris_test   mt001  sr1_0001  34.080655 -107.214079     2202.8
# 7   iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 8   iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 9   iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 10  iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 11  iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 12  iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 13  iris_test   mt001  sr1_0002  34.080655 -107.214079     2202.8
# 14  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 15  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 16  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 17  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 18  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 19  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 20  iris_test   mt001  sr1_0003  34.080655 -107.214079     2202.8
# 21  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 22  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 23  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 24  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 25  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 26  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 27  iris_test   mt001  sr1_0004  34.080655 -107.214079     2202.8
# 28  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 29  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 30  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 31  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 32  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 33  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
# 34  iris_test   mt001  sr1_0005  34.080655 -107.214079     2202.8
#
#         component                     start                       end  \
# 0              bx 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 1              by 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 2              bz 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 3              e1 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 4              e2 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 5   temperature_e 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 6   temperature_h 2020-09-30 20:21:00+00:00 2020-09-30 20:28:15+00:00
# 7              bx 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 8              by 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 9              bz 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 10             e1 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 11             e2 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 12  temperature_e 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 13  temperature_h 2020-09-30 20:29:00+00:00 2020-09-30 20:42:16+00:00
# 14             bx 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 15             by 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 16             bz 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 17             e1 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 18             e2 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 19  temperature_e 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 20  temperature_h 2020-09-30 20:54:00+00:00 2020-09-30 21:11:01+00:00
# 21             bx 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 22             by 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 23             bz 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 24             e1 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 25             e2 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 26  temperature_e 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 27  temperature_h 2020-09-30 21:12:00+00:00 2020-09-30 21:13:45+00:00
# 28             bx 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 29             by 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 30             bz 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 31             e1 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 32             e2 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 33  temperature_e 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
# 34  temperature_h 2020-09-30 21:14:00+00:00 2020-10-07 17:05:46+00:00
#
#     n_samples  sample_rate measurement_type  azimuth  tilt units  \
# 0         436          1.0         magnetic      0.0   0.0  none
# 1         436          1.0         magnetic      0.0   0.0  none
# 2         436          1.0         magnetic      0.0   0.0  none
# 3         436          1.0         electric      0.0   0.0  none
# 4         436          1.0         electric      0.0   0.0  none
# 5         436          1.0        auxiliary      0.0   0.0  none
# 6         436          1.0        auxiliary      0.0   0.0  none
# 7         797          1.0         magnetic      0.0   0.0  none
# 8         797          1.0         magnetic      0.0   0.0  none
# 9         797          1.0         magnetic      0.0   0.0  none
# 10        797          1.0         electric      0.0   0.0  none
# 11        797          1.0         electric      0.0   0.0  none
# 12        797          1.0        auxiliary      0.0   0.0  none
# 13        797          1.0        auxiliary      0.0   0.0  none
# 14       1022          1.0         magnetic      0.0   0.0  none
# 15       1022          1.0         magnetic      0.0   0.0  none
# 16       1022          1.0         magnetic      0.0   0.0  none
# 17       1022          1.0         electric      0.0   0.0  none
# 18       1022          1.0         electric      0.0   0.0  none
# 19       1022          1.0        auxiliary      0.0   0.0  none
# 20       1022          1.0        auxiliary      0.0   0.0  none
# 21        106          1.0         magnetic      0.0   0.0  none
# 22        106          1.0         magnetic      0.0   0.0  none
# 23        106          1.0         magnetic      0.0   0.0  none
# 24        106          1.0         electric      0.0   0.0  none
# 25        106          1.0         electric      0.0   0.0  none
# 26        106          1.0        auxiliary      0.0   0.0  none
# 27        106          1.0        auxiliary      0.0   0.0  none
# 28     589907          1.0         magnetic      0.0   0.0  none
# 29     589907          1.0         magnetic      0.0   0.0  none
# 30     589907          1.0         magnetic      0.0   0.0  none
# 31     589907          1.0         electric      0.0   0.0  none
# 32     589907          1.0         electric      0.0   0.0  none
# 33     589907          1.0        auxiliary      0.0   0.0  none
# 34     589907          1.0        auxiliary      0.0   0.0  none
#
#              hdf5_reference       run_hdf5_reference   station_hdf5_reference
# 0   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 1   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 2   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 3   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 4   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 5   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 6   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 7   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 8   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 9   <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 10  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 11  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 12  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 13  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 14  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 15  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 16  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 17  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 18  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 19  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 20  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 21  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 22  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 23  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 24  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 25  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 26  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 27  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 28  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 29  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 30  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 31  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 32  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 33  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>
# 34  <HDF5 object reference>  <HDF5 object reference>  <HDF5 object reference>

# %% [markdown]
# ### Plot a Run
#
# Let's have a look at one of the runs.  Run `sr1_0005` was the longest, lets try to look at that one. This can take a bit of time since it was 7 days of data.
#
# Notice the dirunal variations caused by just temperature.  Looks like there was something at day `2020-10-06` that caused a spike, so lets grab just the first few days.

# %%
run_group = m.get_run("mt001", "sr1_0005", survey="iris_test")
run_ts_object = run_group.to_runts(start="2020-10-01T00:00:00", n_samples=86400*4)
# Out:
# 2022-12-13 19:41:11,191 [line 458] mth5.timeseries.run_ts.RunTS.validate_metadata - WARNING: start time of dataset 2020-10-01T00:00:00+00:00 does not match metadata start 2020-09-30T21:14:00+00:00 updating metatdata value to 2020-10-01T00:00:00+00:00
# 2022-12-13 19:41:11,196 [line 472] mth5.timeseries.run_ts.RunTS.validate_metadata - WARNING: end time of dataset 2020-10-04T23:59:59+00:00 does not match metadata end 2020-10-07T17:05:46+00:00 updating metatdata value to 2020-10-04T23:59:59+00:00

# %%
print(run_group.metadata)
# Out:
# run:
# 	channels_recorded_auxiliary = ['temperature_e', 'temperature_h']
# 	channels_recorded_electric = ['e1', 'e2']
# 	channels_recorded_magnetic = ['bx', 'by', 'bz']
# 	data_logger.firmware.author = None
# 	data_logger.firmware.name = None
# 	data_logger.firmware.version = None
# 	data_logger.id = None
# 	data_logger.manufacturer = LEMI
# 	data_logger.model = LEMI424
# 	data_logger.power_source.voltage.end = 12.6
# 	data_logger.power_source.voltage.start = 13.01
# 	data_logger.timing_system.drift = 0.0
# 	data_logger.timing_system.type = GPS
# 	data_logger.timing_system.uncertainty = 0.0
# 	data_logger.type = None
# 	data_type = BBMT
# 	hdf5_reference = <HDF5 object reference>
# 	id = sr1_0005
# 	mth5_type = Run
# 	sample_rate = 1.0
# 	time_period.end = 2020-10-07T17:05:46+00:00
# 	time_period.start = 2020-09-30T21:14:00+00:00

# %%
run_plot = run_ts_object.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Close the MTH5
#
# This is important, you should close the file after you are done using it.  Otherwise bad things can happen if you try to open it with another program or Python interpreter.

# %%
m.close_mth5()
# Out:
# 2022-12-13 19:41:12,735 [line 755] mth5.mth5.MTH5.close_mth5 - INFO: Flushing and closing C:\Users\jpeacock\OneDrive - DOI\Documents\GitHub\mt_examples\data\time_series\lemi\from_lemi.h5
